# %%
import pandas as pd

# %%
df = pd.read_csv('employee.csv')

# %%
df
# Out:
#         name  gender  department    salary
# 0       John    male          IT  500000.0
# 1  Elizabeth  female          IT  600000.0
# 2       Rita  female  Accountant  450000.0
# 3       Paul    male       Sales  300000.0
# 4    Timothy    male       Sales  400000.0
# 5      Dammy  female     Manager       NaN
# 6     George     NaN   Executive  750000.0
# 7      Wendy  female         NaN  400000.0
# 8   Precious    male   Executive  800000.0

# %%
df2 = df.copy()

# %%
df2
# Out:
#         name  gender  department    salary
# 0       John    male          IT  500000.0
# 1  Elizabeth  female          IT  600000.0
# 2       Rita  female  Accountant  450000.0
# 3       Paul    male       Sales  300000.0
# 4    Timothy    male       Sales  400000.0
# 5      Dammy  female     Manager       NaN
# 6     George     NaN   Executive  750000.0
# 7      Wendy  female         NaN  400000.0
# 8   Precious    male   Executive  800000.0

# %%
df2['salary'].mean()
# Out:
# 525000.0

# %%
df2['salary'].fillna(df2['salary'].mean())
# Out:
# 0    500000.0
# 1    600000.0
# 2    450000.0
# 3    300000.0
# 4    400000.0
# 5    525000.0
# 6    750000.0
# 7    400000.0
# 8    800000.0
# Name: salary, dtype: float64

# %%
df2
# Out:
#         name  gender  department    salary
# 0       John    male          IT  500000.0
# 1  Elizabeth  female          IT  600000.0
# 2       Rita  female  Accountant  450000.0
# 3       Paul    male       Sales  300000.0
# 4    Timothy    male       Sales  400000.0
# 5      Dammy  female     Manager       NaN
# 6     George     NaN   Executive  750000.0
# 7      Wendy  female         NaN  400000.0
# 8   Precious    male   Executive  800000.0

# %%
df2['salary'].mean()
# Out:
# 525000.0

# %%
df2['salary'] = df2['salary'].fillna(df2['salary'].mean())

# %%
df2['salary'].fillna(df2['salary'].mean(), inplace=True)

# %%
df2
# Out:
#         name  gender  department    salary
# 0       John    male          IT  500000.0
# 1  Elizabeth  female          IT  600000.0
# 2       Rita  female  Accountant  450000.0
# 3       Paul    male       Sales  300000.0
# 4    Timothy    male       Sales  400000.0
# 5      Dammy  female     Manager  525000.0
# 6     George     NaN   Executive  750000.0
# 7      Wendy  female         NaN  400000.0
# 8   Precious    male   Executive  800000.0

# %%
df2['salary'].median()
# Out:
# 500000.0

# %%
df2['salary'].mode()
# Out:
# 0    400000.0
# dtype: float64

# %%
df3 = df.copy()

# %%
df3
# Out:
#         name  gender  department    salary
# 0       John    male          IT  500000.0
# 1  Elizabeth  female          IT  600000.0
# 2       Rita  female  Accountant  450000.0
# 3       Paul    male       Sales  300000.0
# 4    Timothy    male       Sales  400000.0
# 5      Dammy  female     Manager       NaN
# 6     George     NaN   Executive  750000.0
# 7      Wendy  female         NaN  400000.0
# 8   Precious    male   Executive  800000.0

# %%
df3['salary'].fillna(123456, inplace=True)

# %%
df3
# Out:
#         name  gender  department    salary
# 0       John    male          IT  500000.0
# 1  Elizabeth  female          IT  600000.0
# 2       Rita  female  Accountant  450000.0
# 3       Paul    male       Sales  300000.0
# 4    Timothy    male       Sales  400000.0
# 5      Dammy  female     Manager  123456.0
# 6     George     NaN   Executive  750000.0
# 7      Wendy  female         NaN  400000.0
# 8   Precious    male   Executive  800000.0

# %%
df3['department'].fillna('Others', inplace=True)

# %%
df3
# Out:
#         name  gender  department    salary
# 0       John    male          IT  500000.0
# 1  Elizabeth  female          IT  600000.0
# 2       Rita  female  Accountant  450000.0
# 3       Paul    male       Sales  300000.0
# 4    Timothy    male       Sales  400000.0
# 5      Dammy  female     Manager  123456.0
# 6     George     NaN   Executive  750000.0
# 7      Wendy  female      Others  400000.0
# 8   Precious    male   Executive  800000.0

# %%
df3['department'].replace('IT', 'ICT', inplace=True)

# %%
df3
# Out:
#         name  gender  department    salary
# 0       John    male         ICT  500000.0
# 1  Elizabeth  female         ICT  600000.0
# 2       Rita  female  Accountant  450000.0
# 3       Paul    male       Sales  300000.0
# 4    Timothy    male       Sales  400000.0
# 5      Dammy  female     Manager  123456.0
# 6     George     NaN   Executive  750000.0
# 7      Wendy  female      Others  400000.0
# 8   Precious    male   Executive  800000.0

# %%
df[df['name'] == 'George']
# Out:
#      name gender department    salary
# 6  George    NaN  Executive  750000.0

# %%
df3.loc[(df3['name'] == 'George'), 'gender'] = 'male'

# %%
df3
# Out:
#         name  gender  department    salary
# 0       John    male         ICT  500000.0
# 1  Elizabeth  female         ICT  600000.0
# 2       Rita  female  Accountant  450000.0
# 3       Paul    male       Sales  300000.0
# 4    Timothy    male       Sales  400000.0
# 5      Dammy  female     Manager  123456.0
# 6     George    male   Executive  750000.0
# 7      Wendy  female      Others  400000.0
# 8   Precious    male   Executive  800000.0

# %%
df4 = df.copy()

# %%
df4
# Out:
#         name  gender  department    salary
# 0       John    male          IT  500000.0
# 1  Elizabeth  female          IT  600000.0
# 2       Rita  female  Accountant  450000.0
# 3       Paul    male       Sales  300000.0
# 4    Timothy    male       Sales  400000.0
# 5      Dammy  female     Manager       NaN
# 6     George     NaN   Executive  750000.0
# 7      Wendy  female         NaN  400000.0
# 8   Precious    male   Executive  800000.0

# %%
df4.fillna('Unknown', inplace=True)

# %%
df4
# Out:
#         name   gender  department   salary
# 0       John     male          IT   500000
# 1  Elizabeth   female          IT   600000
# 2       Rita   female  Accountant   450000
# 3       Paul     male       Sales   300000
# 4    Timothy     male       Sales   400000
# 5      Dammy   female     Manager  Unknown
# 6     George  Unknown   Executive   750000
# 7      Wendy   female     Unknown   400000
# 8   Precious     male   Executive   800000

# %%
df5 = df.copy()

# %%
df5
# Out:
#         name  gender  department    salary
# 0       John    male          IT  500000.0
# 1  Elizabeth  female          IT  600000.0
# 2       Rita  female  Accountant  450000.0
# 3       Paul    male       Sales  300000.0
# 4    Timothy    male       Sales  400000.0
# 5      Dammy  female     Manager       NaN
# 6     George     NaN   Executive  750000.0
# 7      Wendy  female         NaN  400000.0
# 8   Precious    male   Executive  800000.0

# %%
df5.dtypes['salary'] == 'float64'
# Out:
# True

# %%
df5.columns
# Out:
# Index(['name', 'gender', 'department', 'salary'], dtype='object')

# %%
df5.dtypes['name']
# Out:
# dtype('O')

# %%
for i in df5.columns:
    if df5.dtypes[i] == 'float64':
        df5[i].fillna(df5[i].mean(), inplace=True)

# %%
df5
# Out:
#         name  gender  department    salary
# 0       John    male          IT  500000.0
# 1  Elizabeth  female          IT  600000.0
# 2       Rita  female  Accountant  450000.0
# 3       Paul    male       Sales  300000.0
# 4    Timothy    male       Sales  400000.0
# 5      Dammy  female     Manager  525000.0
# 6     George     NaN   Executive  750000.0
# 7      Wendy  female         NaN  400000.0
# 8   Precious    male   Executive  800000.0
