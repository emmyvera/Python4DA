# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('medals_by_country_2016.csv')

# %%
df.head()
# Out:
#       Unnamed: 0  Bronze  Gold  Silver
# 0  United States      67   137      52
# 1        Germany      67    47      43
# 2  Great Britain      26    64      55
# 3         Russia      35    50      28
# 4          China      35    44      30

# %%
df.rename(columns={'Unnamed: 0' : 'Country'}, inplace=True)

# %%
df
# Out:
#          Country  Bronze  Gold  Silver
# 0  United States      67   137      52
# 1        Germany      67    47      43
# 2  Great Britain      26    64      55
# 3         Russia      35    50      28
# 4          China      35    44      30
# 5         France      21    20      55
# 6      Australia      25    23      34
# 7          Italy      24     8      38
# 8         Canada      61     4       4
# 9          Japan      34    17      13

# %%
fig, ax = plt.subplots()
ax.bar(df['Country'], df["Gold"])
plt.show()

# %%
fig, ax = plt.subplots()
ax.bar(df['Country'], df["Gold"])
ax.set_xticklabels(df['Country'], rotation=80)
ax.set_ylabel("Number of medals")
plt.show()
# Out:
# c:\users\emmyvera\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fig, ax = plt.subplots()
ax.bar(df['Country'], df["Silver"])
ax.set_xticklabels(df['Country'], rotation=80)
ax.set_ylabel("Number of medals")
plt.show()
# Out:
# c:\users\emmyvera\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fig, ax = plt.subplots()
ax.bar(df['Country'], df["Bronze"])
ax.set_xticklabels(df['Country'], rotation=80)
ax.set_ylabel("Number of medals")
plt.show()
# Out:
# c:\users\emmyvera\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fig, ax = plt.subplots()
ax.bar(df['Country'], df["Gold"])
ax.bar(df['Country'], df["Silver"], bottom=df["Gold"])
ax.set_xticklabels(df['Country'], rotation=90)
ax.set_ylabel("Number of medals")
plt.show()
# Out:
# c:\users\emmyvera\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   after removing the cwd from sys.path.

# %%
fig, ax = plt.subplots()
ax.bar(df['Country'], df["Gold"])#Gold
ax.bar(df['Country'], df["Silver"], bottom=df["Gold"])#Silver
ax.bar(df['Country'], df["Bronze"], bottom=df["Gold"]+df['Silver'])#Bronze
ax.set_xticklabels(df['Country'], rotation=90)
ax.set_ylabel("Number of medals")
plt.show()
# Out:
# c:\users\emmyvera\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   """

# %%
fig, ax = plt.subplots()
ax.bar(df['Country'], df["Gold"], label = 'Gold')#Gold
ax.bar(df['Country'], df["Silver"], bottom=df["Gold"], label='Silver')#Silver
ax.bar(df['Country'], df["Bronze"], bottom=df["Gold"]+df['Silver'], label='Bronze')#Bronze
ax.set_xticklabels(df['Country'], rotation=90)
ax.set_ylabel("Number of medals")
ax.legend()
plt.show()
# Out:
# c:\users\emmyvera\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   """
